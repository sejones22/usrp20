# %%
import lightkurve as lk

# %%
search_result = lk.search_targetpixelfile('G 227-22', mission='TESS', sector=1)

# %%
tpf = search_result.download(quality_bitmask='default')
# Out:
# /home/sejones/anaconda3/lib/python3.7/site-packages/lightkurve/search.py:225: LightkurveWarning: Cannot download from an empty search result.
#   LightkurveWarning)

# %%
search_result
# Out:
# SearchResult containing 0 data products.

# %%
# %matplotlib inline

# %%
tpf.plot(aperture_mask=tpf.pipeline_mask);

# %%
lc = tpf.to_lightcurve()

# %%
lc.errorbar();
